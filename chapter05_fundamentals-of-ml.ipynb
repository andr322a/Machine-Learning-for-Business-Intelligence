# %% [markdown]
# <a href="https://colab.research.google.com/github/andr322a/Machine-Learning-for-Business-Intelligence/blob/main/chapter05_fundamentals-of-ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is a companion notebook for the book [Deep Learning with Python, Third Edition](https://www.manning.com/books/deep-learning-with-python-third-edition). For readability, it only contains runnable code blocks and section titles, and omits everything else in the book: text paragraphs, figures, and pseudocode.
#
# **If you want to be able to follow what's going on, I recommend reading the notebook side by side with your copy of the book.**
#
# The book's contents are available online at [deeplearningwithpython.io](https://deeplearningwithpython.io).

# %%
# !pip install keras keras-hub --upgrade -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 76.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 87.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# keras-nlp 0.26.0 requires keras-hub==0.26.0, but you have keras-hub 0.29.0 which is incompatible.

# %%
import os
os.environ["KERAS_BACKEND"] = "jax"

# %%
# @title
import os
from IPython.core.magic import register_cell_magic

@register_cell_magic
def backend(line, cell):
    current, required = os.environ.get("KERAS_BACKEND", ""), line.split()[-1]
    if current == required:
        get_ipython().run_cell(cell)
    else:
        print(
            f"This cell requires the {required} backend. To run it, change KERAS_BACKEND to "
            f"\"{required}\" at the top of the notebook, restart the runtime, and rerun the notebook."
        )

# %% [markdown]
# ## Fundamentals of machine learning

# %% [markdown]
# ### Generalization: The goal of machine learning

# %% [markdown]
# #### Underfitting and overfitting

# %% [markdown]
# ##### Noisy training data

# %% [markdown]
# ##### Ambiguous features

# %% [markdown]
# ##### Rare features and spurious correlations

# %%
from keras.datasets import mnist
import numpy as np

(train_images, train_labels), _ = mnist.load_data()
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255

train_images_with_noise_channels = np.concatenate(
    [train_images, np.random.random((len(train_images), 784))], axis=1
)

train_images_with_zeros_channels = np.concatenate(
    [train_images, np.zeros((len(train_images), 784))], axis=1
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
import keras
from keras import layers

def get_model():
    model = keras.Sequential(
        [
            layers.Dense(512, activation="relu"),
            layers.Dense(10, activation="softmax"),
        ]
    )
    model.compile(
        optimizer="adam",
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    return model

model = get_model()
history_noise = model.fit(
    train_images_with_noise_channels,
    train_labels,
    epochs=10,
    batch_size=128,
    validation_split=0.2,
)

model = get_model()
history_zeros = model.fit(
    train_images_with_zeros_channels,
    train_labels,
    epochs=10,
    batch_size=128,
    validation_split=0.2,
)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8629 - loss: 0.4504 - val_accuracy: 0.9198 - val_loss: 0.2704
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9291 - loss: 0.2381 - val_accuracy: 0.9339 - val_loss: 0.2227
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9513 - loss: 0.1633 - val_accuracy: 0.9496 - val_loss: 0.1704
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9648 - loss: 0.1196 - val_accuracy: 0.9549 - val_loss: 0.1530
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9755 - loss: 0.0844 - val_accuracy: 0.9592 - val_loss: 0.1396
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9808 - loss: 0.0647 - val_accuracy: 0.9610 - val_loss: 0.1305
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9884 - loss: 0.0425 - val_accuracy: 0.9599 - val_loss: 0.1420
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9919 - loss: 0.0314 - val_accuracy: 0.9623 - val_loss: 0.1308
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9958 - loss: 0.0191 - val_accuracy: 0.9626 - val_loss: 0.1287
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9972 - loss: 0.0140 - val_accuracy: 0.9634 - val_loss: 0.1306
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9150 - loss: 0.3008 - val_accuracy: 0.9578 - val_loss: 0.1527
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9639 - loss: 0.1266 - val_accuracy: 0.9663 - val_loss: 0.1117
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9768 - loss: 0.0811 - val_accuracy: 0.9699 - val_loss: 0.0980
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9833 - loss: 0.0578 - val_accuracy: 0.9752 - val_loss: 0.0846
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9873 - loss: 0.0429 - val_accuracy: 0.9749 - val_loss: 0.0826
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9920 - loss: 0.0310 - val_accuracy: 0.9775 - val_loss: 0.0773
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9940 - loss: 0.0235 - val_accuracy: 0.9774 - val_loss: 0.0761
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9953 - loss: 0.0182 - val_accuracy: 0.9791 - val_loss: 0.0752
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9970 - loss: 0.0136 - val_accuracy: 0.9762 - val_loss: 0.0840
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9974 - loss: 0.0110 - val_accuracy: 0.9772 - val_loss: 0.0796

# %%
import matplotlib.pyplot as plt

val_acc_noise = history_noise.history["val_accuracy"]
val_acc_zeros = history_zeros.history["val_accuracy"]
epochs = range(1, 11)
plt.plot(
    epochs,
    val_acc_noise,
    "b-",
    label="Validation accuracy with noise channels",
)
plt.plot(
    epochs,
    val_acc_zeros,
    "r--",
    label="Validation accuracy with zeros channels",
)
plt.title("Effect of noise channels on validation accuracy")
plt.xlabel("Epochs")
plt.xticks(epochs)
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# #### The nature of generalization in deep learning

# %%
(train_images, train_labels), _ = mnist.load_data()
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255

random_train_labels = train_labels[:]
np.random.shuffle(random_train_labels)

model = keras.Sequential(
    [
        layers.Dense(512, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)
model.compile(
    optimizer="rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
model.fit(
    train_images,
    random_train_labels,
    epochs=100,
    batch_size=128,
    validation_split=0.2,
)
# Out:
# Epoch 1/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.1037 - loss: 2.3147 - val_accuracy: 0.1023 - val_loss: 2.3060
# Epoch 2/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1170 - loss: 2.2987 - val_accuracy: 0.1082 - val_loss: 2.3130
# Epoch 3/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1274 - loss: 2.2917 - val_accuracy: 0.1048 - val_loss: 2.3151
# Epoch 4/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1374 - loss: 2.2800 - val_accuracy: 0.0993 - val_loss: 2.3290
# Epoch 5/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.1489 - loss: 2.2650 - val_accuracy: 0.1032 - val_loss: 2.3326
# Epoch 6/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.1634 - loss: 2.2463 - val_accuracy: 0.0957 - val_loss: 2.3502
# Epoch 7/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.1782 - loss: 2.2233 - val_accuracy: 0.0999 - val_loss: 2.3641
# Epoch 8/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1928 - loss: 2.1985 - val_accuracy: 0.1023 - val_loss: 2.3748
# Epoch 9/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2099 - loss: 2.1691 - val_accuracy: 0.0988 - val_loss: 2.3990
# Epoch 10/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2249 - loss: 2.1364 - val_accuracy: 0.1028 - val_loss: 2.4129
# Epoch 11/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2427 - loss: 2.1020 - val_accuracy: 0.1010 - val_loss: 2.4531
# Epoch 12/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2607 - loss: 2.0667 - val_accuracy: 0.0984 - val_loss: 2.4696
# Epoch 13/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2739 - loss: 2.0302 - val_accuracy: 0.1028 - val_loss: 2.4992
# Epoch 14/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.2950 - loss: 1.9919 - val_accuracy: 0.1005 - val_loss: 2.5259
# Epoch 15/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3111 - loss: 1.9535 - val_accuracy: 0.1032 - val_loss: 2.5582
# Epoch 16/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3253 - loss: 1.9166 - val_accuracy: 0.1018 - val_loss: 2.6011
# Epoch 17/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3416 - loss: 1.8778 - val_accuracy: 0.1019 - val_loss: 2.6228
# Epoch 18/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3599 - loss: 1.8377 - val_accuracy: 0.1019 - val_loss: 2.6733
# Epoch 19/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3736 - loss: 1.8001 - val_accuracy: 0.1018 - val_loss: 2.6938
# Epoch 20/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3916 - loss: 1.7620 - val_accuracy: 0.1039 - val_loss: 2.7441
# Epoch 21/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.
100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8423 - loss: 0.4964 - val_accuracy: 0.0997 - val_loss: 6.5612
# Epoch 83/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8481 - loss: 0.4864 - val_accuracy: 0.1007 - val_loss: 6.6604
# Epoch 84/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8502 - loss: 0.4779 - val_accuracy: 0.1038 - val_loss: 6.6928
# Epoch 85/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8525 - loss: 0.4690 - val_accuracy: 0.1012 - val_loss: 6.7485
# Epoch 86/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8543 - loss: 0.4611 - val_accuracy: 0.1017 - val_loss: 6.8588
# Epoch 87/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8588 - loss: 0.4497 - val_accuracy: 0.0998 - val_loss: 6.9261
# Epoch 88/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8607 - loss: 0.4443 - val_accuracy: 0.1040 - val_loss: 7.0313
# Epoch 89/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8636 - loss: 0.4344 - val_accuracy: 0.1005 - val_loss: 7.1021
# Epoch 90/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8667 - loss: 0.4289 - val_accuracy: 0.0993 - val_loss: 7.1882
# Epoch 91/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8676 - loss: 0.4184 - val_accuracy: 0.0988 - val_loss: 7.2663
# Epoch 92/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8717 - loss: 0.4117 - val_accuracy: 0.1016 - val_loss: 7.3188
# Epoch 93/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8746 - loss: 0.4029 - val_accuracy: 0.1007 - val_loss: 7.4065
# Epoch 94/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8769 - loss: 0.3976 - val_accuracy: 0.1022 - val_loss: 7.4370
# Epoch 95/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8796 - loss: 0.3878 - val_accuracy: 0.1012 - val_loss: 7.5771
# Epoch 96/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8814 - loss: 0.3833 - val_accuracy: 0.1004 - val_loss: 7.6163
# Epoch 97/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8835 - loss: 0.3774 - val_accuracy: 0.0976 - val_loss: 7.6846
# Epoch 98/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8874 - loss: 0.3682 - val_accuracy: 0.0999 - val_loss: 7.7567
# Epoch 99/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8869 - loss: 0.3639 - val_accuracy: 0.0984 - val_loss: 7.7827
# Epoch 100/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8892 - loss: 0.3563 - val_accuracy: 0.1002 - val_loss: 7.9155

# %% [markdown]
# ##### The manifold hypothesis

# %% [markdown]
# ##### Interpolation as a source of generalization

# %% [markdown]
# ##### Why deep learning works

# %% [markdown]
# ##### Training data is paramount

# %% [markdown]
# ### Evaluating machine-learning models

# %% [markdown]
# #### Training, validation, and test sets

# %% [markdown]
# ##### Simple hold-out validation

# %% [markdown]
# ##### K-fold validation

# %% [markdown]
# ##### Iterated K-fold validation with shuffling

# %% [markdown]
# #### Beating a common-sense baseline

# %% [markdown]
# #### Things to keep in mind about model evaluation

# %% [markdown]
# ### Improving model fit

# %% [markdown]
# #### Tuning key gradient descent parameters

# %%
(train_images, train_labels), _ = mnist.load_data()
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255

model = keras.Sequential(
    [
        layers.Dense(512, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)
model.compile(
    optimizer=keras.optimizers.RMSprop(learning_rate=1.0),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
model.fit(
    train_images, train_labels, epochs=10, batch_size=128, validation_split=0.2
)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.2931 - loss: 549.3840 - val_accuracy: 0.2062 - val_loss: 2.2674
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1969 - loss: 3.3969 - val_accuracy: 0.1873 - val_loss: 2.2990
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1805 - loss: 2.4579 - val_accuracy: 0.1873 - val_loss: 2.3512
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1842 - loss: 2.5437 - val_accuracy: 0.1404 - val_loss: 2.3200
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1767 - loss: 2.4320 - val_accuracy: 0.1772 - val_loss: 2.2327
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1869 - loss: 2.2673 - val_accuracy: 0.1757 - val_loss: 2.1674
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.
# Epoch 14/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9976 - loss: 0.0100 - val_accuracy: 0.9792 - val_loss: 0.2374
# Epoch 15/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9983 - loss: 0.0072 - val_accuracy: 0.9779 - val_loss: 0.2230
# Epoch 16/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9986 - loss: 0.0069 - val_accuracy: 0.9808 - val_loss: 0.2243
# Epoch 17/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9992 - loss: 0.0050 - val_accuracy: 0.9803 - val_loss: 0.2416
# Epoch 18/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9994 - loss: 0.0024 - val_accuracy: 0.9821 - val_loss: 0.2305
# Epoch 19/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9997 - loss: 0.0016 - val_accuracy: 0.9818 - val_loss: 0.2274
# Epoch 20/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9994 - loss: 0.0023 - val_accuracy: 0.9809 - val_loss: 0.2660

# %%
val_loss = history_very_large_model.history["val_loss"]
epochs = range(1, 21)
plt.plot(epochs, val_loss, "b-", label="Validation loss")
plt.title("Validation loss for a model with too much capacity")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# ### Improving generalization

# %% [markdown]
# #### Dataset curation

# %% [markdown]
# #### Feature engineering

# %% [markdown]
# #### Using early stopping

# %% [markdown]
# #### Regularizing your model

# %% [markdown]
# ##### Reducing the network's size

# %%
from keras.datasets import imdb

(train_data, train_labels), _ = imdb.load_data(num_words=10000)

def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.0
    return results

train_data = vectorize_sequences(train_data)

model = keras.Sequential(
    [
        layers.Dense(16, activation="relu"),
        layers.Dense(16, activation="relu"),
        layers.Dense(1, activation="sigmoid"),
    ]
)
model.compile(
    optimizer="rmsprop",
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
history_original = model.fit(
    train_data,
    train_labels,
    epochs=20,
    batch_size=512,
    validation_split=0.4,
)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 104ms/step - accuracy: 0.7756 - loss: 0.5582 - val_accuracy: 0.8591 - val_loss: 0.4385
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.8847 - loss: 0.3616 - val_accuracy: 0.8788 - val_loss: 0.3397
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9099 - loss: 0.2738 - val_accuracy: 0.8780 - val_loss: 0.3107
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9285 - loss: 0.2182 - val_accuracy: 0.8863 - val_loss: 0.2812
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9385 - loss: 0.1842 - val_accuracy: 0.8907 - val_loss: 0.2738
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9477 - loss: 0.1599 - val_accuracy: 0.8881 - val_loss: 0.2807
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9584 - loss: 0.1332 - val_accuracy: 0.8752 - val_loss: 0.3302
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9629 - loss: 0.1201 - val_accuracy: 0.8786 - val_loss: 0.3151
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9699 - loss: 0.1031 - val_accuracy: 0.8814 - val_loss: 0.3151
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9735 - loss: 0.0928 - val_accuracy: 0.8816 - val_loss: 0.3232
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9793 - loss: 0.0803 - val_accuracy: 0.8765 - val_loss: 0.3568
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9810 - loss: 0.0721 - val_accuracy: 0.8764 - val_loss: 0.3664
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9853 - loss: 0.0621 - val_accuracy: 0.8776 - val_loss: 0.3768
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9884 - loss: 0.0524 - val_accuracy: 0.8703 - val_loss: 0.4260
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9894 - loss: 0.0496 - val_accuracy: 0.8750 - val_loss: 0.4203
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9927 - loss: 0.0389 - val_accuracy: 0.8738 - val_loss: 0.4437
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9929 - loss: 0.0357 - val_accuracy: 0.8747 - val_loss: 0.4558
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9954 - loss: 0.0298 - val_accuracy: 0.8622 - val_loss: 0.5392
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9961 - loss: 0.0252 - val_accuracy: 0.8634 - val_loss: 0.5709
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9970 - loss: 0.0217 - val_accuracy: 0.8720 - val_loss: 0.5262

# %%
model = keras.Sequential(
    [
        layers.Dense(4, activation="relu"),
        layers.Dense(4, activation="relu"),
        layers.Dense(1, activation="sigmoid"),
    ]
)
model.compile(
    optimizer="rmsprop",
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
history_smaller_model = model.fit(
    train_data,
    train_labels,
    epochs=20,
    batch_size=512,
    validation_split=0.4,
)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.6389 - loss: 0.6288 - val_accuracy: 0.7165 - val_loss: 0.5766
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.7772 - loss: 0.5453 - val_accuracy: 0.7842 - val_loss: 0.5304
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.8345 - loss: 0.4989 - val_accuracy: 0.8144 - val_loss: 0.5022
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8707 - loss: 0.4653 - val_accuracy: 0.8072 - val_loss: 0.4895
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8932 - loss: 0.4385 - val_accuracy: 0.8285 - val_loss: 0.4742
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9115 - loss: 0.4160 - val_accuracy: 0.8437 - val_loss: 0.4621
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9265 - loss: 0.3962 - val_accuracy: 0.8465 - val_loss: 0.4580
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9387 - loss: 0.3788 - val_accuracy: 0.8723 - val_loss: 0.4400
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9463 - loss: 0.3633 - val_accuracy: 0.8520 - val_loss: 0.4545
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.9549 - loss: 0.3486 - val_accuracy: 0.8632 - val_loss: 0.4446
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9623 - loss: 0.3353 - val_accuracy: 0.8642 - val_loss: 0.4458
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9669 - loss: 0.3226 - val_accuracy: 0.8747 - val_loss: 0.4332
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9705 - loss: 0.3109 - val_accuracy: 0.8728 - val_loss: 0.4382
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9735 - loss: 0.3004 - val_accuracy: 0.8689 - val_loss: 0.4474
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9776 - loss: 0.2893 - val_accuracy: 0.8727 - val_loss: 0.4431
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9806 - loss: 0.2794 - val_accuracy: 0.8741 - val_loss: 0.4390
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9836 - loss: 0.2704 - val_accuracy: 0.8676 - val_loss: 0.4634
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9845 - loss: 0.2612 - val_accuracy: 0.8734 - val_loss: 0.4413
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9860 - loss: 0.2533 - val_accuracy: 0.8692 - val_loss: 0.4707
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9873 - loss: 0.2450 - val_accuracy: 0.8710 - val_loss: 0.4584

# %%
original_val_loss = history_original.history["val_loss"]
smaller_model_val_loss = history_smaller_model.history["val_loss"]
epochs = range(1, 21)
plt.plot(
    epochs,
    original_val_loss,
    "r--",
    label="Validation loss of original model",
)
plt.plot(
    epochs,
    smaller_model_val_loss,
    "b-",
    label="Validation loss of smaller model",
)
plt.title("Original model vs. smaller model (IMDB review classification)")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.xticks(epochs)
plt.legend()
plt.show()

# %%
model = keras.Sequential(
    [
        layers.Dense(512, activation="relu"),
        layers.Dense(512, activation="relu"),
        layers.Dense(1, activation="sigmoid"),
    ]
)
model.compile(
    optimizer="rmsprop",
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
history_larger_model = model.fit(
    train_data,
    train_labels,
    epochs=20,
    batch_size=512,
    validation_split=0.4,
)

# %%
original_val_loss = history_original.history["val_loss"]
larger_model_val_loss = history_larger_model.history["val_loss"]
epochs = range(1, 21)
plt.plot(
    epochs,
    original_val_loss,
    "r--",
    label="Validation loss of original model",
)
plt.plot(
    epochs,
    larger_model_val_loss,
    "b-",
    label="Validation loss of larger model",
)
plt.title("Original model vs. larger model (IMDB review classification)")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.xticks(epochs)
plt.legend()
plt.show()

# %% [markdown]
# ##### Adding weight regularization

# %%
from keras.regularizers import l2

model = keras.Sequential(
    [
        layers.Dense(16, kernel_regularizer=l2(0.002), activation="relu"),
        layers.Dense(16, kernel_regularizer=l2(0.002), activation="relu"),
        layers.Dense(1, activation="sigmoid"),
    ]
)
model.compile(
    optimizer="rmsprop",
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
history_l2_reg = model.fit(
    train_data,
    train_labels,
    epochs=20,
    batch_size=512,
    validation_split=0.4,
)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - accuracy: 0.7776 - loss: 0.6167 - val_accuracy: 0.8566 - val_loss: 0.4870
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8868 - loss: 0.4187 - val_accuracy: 0.8728 - val_loss: 0.4135
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9117 - loss: 0.3418 - val_accuracy: 0.8860 - val_loss: 0.3714
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9211 - loss: 0.3065 - val_accuracy: 0.8897 - val_loss: 0.3584
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9331 - loss: 0.2798 - val_accuracy: 0.8866 - val_loss: 0.3619
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9343 - loss: 0.2671 - val_accuracy: 0.8749 - val_loss: 0.3868
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9406 - loss: 0.2566 - val_accuracy: 0.8835 - val_loss: 0.3656
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9457 - loss: 0.2456 - val_accuracy: 0.8854 - val_loss: 0.3669
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9455 - loss: 0.2433 - val_accuracy: 0.8811 - val_loss: 0.3787
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9508 - loss: 0.2345 - val_accuracy: 0.8780 - val_loss: 0.3950
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9509 - loss: 0.2295 - val_accuracy: 0.8729 - val_loss: 0.4020
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9560 - loss: 0.2216 - val_accuracy: 0.8712 - val_loss: 0.4091
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9501 - loss: 0.2262 - val_accuracy: 0.8812 - val_loss: 0.3874
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9551 - loss: 0.2187 - val_accuracy: 0.8781 - val_loss: 0.3954
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9595 - loss: 0.2104 - val_accuracy: 0.8775 - val_loss: 0.4006
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9541 - loss: 0.2184 - val_accuracy: 0.8763 - val_loss: 0.4082
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9613 - loss: 0.2068 - val_accuracy: 0.8771 - val_loss: 0.4075
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9611 - loss: 0.2048 - val_accuracy: 0.8565 - val_loss: 0.4839
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9574 - loss: 0.2087 - val_accuracy: 0.8670 - val_loss: 0.4541
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9601 - loss: 0.2055 - val_accuracy: 0.8742 - val_loss: 0.4155

# %%
original_val_loss = history_original.history["val_loss"]
l2_val_loss = history_l2_reg.history["val_loss"]
epochs = range(1, 21)
plt.plot(
    epochs,
    original_val_loss,
    "r--",
    label="Validation loss of original model",
)
plt.plot(
    epochs,
    l2_val_loss,
    "b-",
    label="Validation loss of L2-regularized model",
)
plt.title(
    "Original model vs. L2-regularized model (IMDB review classification)"
)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.xticks(epochs)
plt.legend()
plt.show()

# %%
from keras import regularizers

regularizers.l1(0.001)
regularizers.l1_l2(l1=0.001, l2=0.001)

# %% [markdown]
# ##### Adding dropout

# %%
model = keras.Sequential(
    [
        layers.Dense(16, activation="relu"),
        layers.Dropout(0.5),
        layers.Dense(16, activation="relu"),
        layers.Dropout(0.5),
        layers.Dense(1, activation="sigmoid"),
    ]
)
model.compile(
    optimizer="rmsprop",
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
history_dropout = model.fit(
    train_data,
    train_labels,
    epochs=20,
    batch_size=512,
    validation_split=0.4,
)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.6237 - loss: 0.6455 - val_accuracy: 0.8364 - val_loss: 0.5438
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.7577 - loss: 0.5232 - val_accuracy: 0.8613 - val_loss: 0.4237
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8308 - loss: 0.4194 - val_accuracy: 0.8827 - val_loss: 0.3292
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8669 - loss: 0.3533 - val_accuracy: 0.8852 - val_loss: 0.2951
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8949 - loss: 0.2976 - val_accuracy: 0.8806 - val_loss: 0.2962
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9103 - loss: 0.2577 - val_accuracy: 0.8897 - val_loss: 0.2768
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9217 - loss: 0.2289 - val_accuracy: 0.8899 - val_loss: 0.2808
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9367 - loss: 0.1946 - val_accuracy: 0.8862 - val_loss: 0.3014
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9411 - loss: 0.1768 - val_accuracy: 0.8901 - val_loss: 0.3068
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9449 - loss: 0.1635 - val_accuracy: 0.8839 - val_loss: 0.3342
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9544 - loss: 0.1466 - val_accuracy: 0.8870 - val_loss: 0.3519
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9607 - loss: 0.1233 - val_accuracy: 0.8859 - val_loss: 0.3631
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9624 - loss: 0.1147 - val_accuracy: 0.8853 - val_loss: 0.3931
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9657 - loss: 0.1051 - val_accuracy: 0.8847 - val_loss: 0.3974
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9695 - loss: 0.0988 - val_accuracy: 0.8855 - val_loss: 0.4152
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9711 - loss: 0.0851 - val_accuracy: 0.8839 - val_loss: 0.4646
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9731 - loss: 0.0831 - val_accuracy: 0.8840 - val_loss: 0.5075
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9742 - loss: 0.0794 - val_accuracy: 0.8831 - val_loss: 0.5160
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9742 - loss: 0.0760 - val_accuracy: 0.8852 - val_loss: 0.5153
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9756 - loss: 0.0674 - val_accuracy: 0.8834 - val_loss: 0.5627

# %%
original_val_loss = history_original.history["val_loss"]
dropout_val_loss = history_dropout.history["val_loss"]
epochs = range(1, 21)
plt.plot(
    epochs,
    original_val_loss,
    "r--",
    label="Validation loss of original model",
)
plt.plot(
    epochs,
    dropout_val_loss,
    "b-",
    label="Validation loss of dropout-regularized model",
)
plt.title(
    "Original model vs. dropout-regularized model (IMDB review classification)"
)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.xticks(epochs)
plt.legend()
plt.show()
